# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from game.Bankgames import *
from game.plotting import *
from game.distributions import TruncatedGaussian, Uniform, PiecewiseUniform
import nashpy as nh
from tqdm import tqdm
import pandas as pd

# %%
# Load the data from the Excel file
truncGaussian = pd.read_csv('truncGaussian.xlsx')

# Group by 'case' and randomly select 20 rows for each group
sampled_truncGaussian = truncGaussian.groupby('case').apply(lambda x: x.sample(n=20, replace=True)).reset_index(drop=True)
sampled_truncGaussian
# Out:
# /var/folders/nh/t7y8sbfd52zd2j19h5nfmk_80000gn/T/ipykernel_37377/1530309103.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_truncGaussian = truncGaussian.groupby('case').apply(lambda x: x.sample(n=20, replace=True)).reset_index(drop=True)
#         case  gamma_l  gamma_h   mu  sigma
# 0   (-1, -1)      0.3      0.4  0.6    0.2
# 1   (-1, -1)      0.2      0.6  0.9    0.2
# 2   (-1, -1)      0.1      0.3  0.1    0.2
# 3   (-1, -1)      0.2      0.6  0.9    0.2
# 4   (-1, -1)      0.7      0.8  0.6    0.2
# 5   (-1, -1)      0.7      1.0  0.8    0.2
# 6   (-1, -1)      0.2      0.3  0.8    0.2
# 7   (-1, -1)      0.4      0.9  0.8    0.2
# 8   (-1, -1)      0.4      0.8  0.9    0.2
# ...

# %%
# Load the data from the Excel file
PiecewiseUniform = pd.read_csv('piecewiseUniform.xlsx')

# Group by 'case' and randomly select 20 rows for each group
sampled_piecewiseUniform = PiecewiseUniform.groupby('case').apply(lambda x: x.sample(n=20, replace=True)).reset_index(drop=True)
sampled_piecewiseUniform
# Out:
# /var/folders/nh/t7y8sbfd52zd2j19h5nfmk_80000gn/T/ipykernel_37377/3655094866.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_piecewiseUniform = PiecewiseUniform.groupby('case').apply(lambda x: x.sample(n=20, replace=True)).reset_index(drop=True)
#         case   gamma_l   gamma_h
# 0   (-1, -1)  0.811818  0.821717
# 1   (-1, -1)  0.524747  0.594040
# 2   (-1, -1)  0.910808  0.990000
# 3   (-1, -1)  0.613838  0.693030
# 4   (-1, -1)  0.663333  0.673232
# 5   (-1, -1)  0.435657  0.504949
# 6   (-1, -1)  0.940505  0.950404
# 7   (-1, -1)  0.059495  0.069394
# 8   (-1, -1)  0.683131  0.693030
# 9   (-1, -1)  0.653434  0.722727
# 10  (-1, -1)  0.732626  0.752424
# ...

# %%
sampled_truncGaussian.to_csv('sampled_truncGaussian_2x2',index=False)
sampled_piecewiseUniform.to_csv('sampled_piecewiseUniform_2x2',index=False)
